# %% [markdown]
# Question1
# Write a function that takes a list and a number as arguments. Add the number to the end of
# the list, then remove the first element of the list. The function should then return the updated
# list.
# Examples
# next_in_line([5, 6, 7, 8, 9], 1) ➞ [6, 7, 8, 9, 1]
# next_in_line([7, 6, 3, 23, 17], 10) ➞ [6, 3, 23, 17, 10]
# next_in_line([1, 10, 20, 42 ], 6) ➞ [10, 20, 42, 6]
# next_in_line([], 6) ➞ &quot;No list has been selected&quot;

# %%
def next_in_line(l,x):
    l.append(x)
    l.remove(l[0])
    
    if(len(l)==0):
        return "No list has been selected"
    return l

l = [5, 6, 7, 8, 9]
x = int(input("Enter a num  to append in list : "))
print(next_in_line(l,x))
# Out:
# Enter a num  to append in list : 55
# [6, 7, 8, 9, 55]

# %%
l1 =[]
x = int(input("Enter a num  to append in list : "))
print(next_in_line(l1,x))
# Out:
# Enter a num  to append in list : 9
# No list has been selected

# %% [markdown]
# Question2
# Create the function that takes a list of dictionaries and returns the sum of people&#39;s budgets.
# Examples
# get_budgets([
# { &quot;name&quot;: &quot;John&quot;, &quot;age&quot;: 21, &quot;budget&quot;: 23000 },
# { &quot;name&quot;: &quot;Steve&quot;, &quot;age&quot;: 32, &quot;budget&quot;: 40000 },
# { &quot;name&quot;: &quot;Martin&quot;, &quot;age&quot;: 16, &quot;budget&quot;: 2700 }
# ]) ➞ 65700
# get_budgets([
# { &quot;name&quot;: &quot;John&quot;, &quot;age&quot;: 21, &quot;budget&quot;: 29000 },
# { &quot;name&quot;: &quot;Steve&quot;, &quot;age&quot;: 32, &quot;budget&quot;: 32000 },
# { &quot;name&quot;: &quot;Martin&quot;, &quot;age&quot;: 16, &quot;budget&quot;: 1600 }
# ]) ➞ 62600

# %%
def budget_cal(l):
    sum = 0
    for i in l:
        #print(i,type(i),i['budget'])
        sum  += i['budget']
    return sum

l = [ { "name": "John", "age": 21, "budget": 23000 }, { "name": "Steve", "age": 32, "budget": 40000 }, { "name": "Martin", "age": 16, "budget": 2700 } ]
print("List is : ",l)
print("the sum of people's budgets is : ", budget_cal(l))
# Out:
# List is :  [{'name': 'John', 'age': 21, 'budget': 23000}, {'name': 'Steve', 'age': 32, 'budget': 40000}, {'name': 'Martin', 'age': 16, 'budget': 2700}]
# the sum of people's budgets is :  65700

# %% [markdown]
# Question3
# Create a function that takes a string and returns a string with its letters in alphabetical order.
# Examples
# alphabet_soup(&quot;hello&quot;) ➞ &quot;ehllo&quot;
# alphabet_soup(&quot;edabit&quot;) ➞ &quot;abdeit&quot;
# alphabet_soup(&quot;hacker&quot;) ➞ &quot;acehkr&quot;
# alphabet_soup(&quot;geek&quot;) ➞ &quot;eegk&quot;
# alphabet_soup(&quot;javascript&quot;) ➞ &quot;aacijprstv&quot;

# %%
def alphabet_soup(s):
        return (''.join(sorted(s)))

s = input("Enter a string : ")
alphabet_soup(s)
# Out:
# Enter a string : javascript
# 'aacijprstv'

# %% [markdown]
# Question4
# Suppose that you invest $10,000 for 10 years at an interest rate of 6% compounded monthly.
# What will be the value of your investment at the end of the 10 year period?
# Create a function that accepts the principal p, the term in years t, the interest rate r, and the
# number of compounding periods per year n. The function returns the value at the end of term
# rounded to the nearest cent.
# For the example above:
# compound_interest(10000, 10, 0.06, 12) ➞ 18193.97
# Note that the interest rate is given as a decimal and n=12 because with monthly compounding
# there are 12 periods per year. Compounding can also be done annually, quarterly, weekly, or
# daily.
# Examples
# compound_interest(100, 1, 0.05, 1) ➞ 105.0
# compound_interest(3500, 15, 0.1, 4) ➞ 15399.26
# compound_interest(100000, 20, 0.15, 365) ➞ 2007316.26

# %%
def compound_interest(p,t,r,n):
    
    x = (1 + r/n)**(n*t)
    ci = p*x
    
    return round(ci,2)

p = int(input("Enter principal amount : "))
t = int(input("Enter time in term years : "))
r = float(input("Enter  interest rate : "))
n = int(input("number of compounding periods per year : "))

print("your investment at the end of {0} year is : ".format(t),compound_interest(3500, 15, 0.1, 4))
# Out:
# Enter principal amount : 10
# Enter time in term years : 10
# Enter  interest rate : 0.06
# number of compounding periods per year : 12
# your investment at the end of 10 year is :  15399.26

# %% [markdown]
# Question5
# Write a function that takes a list of elements and returns only the integers.
# Examples
# return_only_integer([9, 2, &quot;space&quot;, &quot;car&quot;, &quot;lion&quot;, 16]) ➞ [9, 2, 16]
# return_only_integer([&quot;hello&quot;, 81, &quot;basketball&quot;, 123, &quot;fox&quot;]) ➞ [81, 123]
# return_only_integer([10, &quot;121&quot;, 56, 20, &quot;car&quot;, 3, &quot;lion&quot;]) ➞ [10, 56, 20,
# 3]
# return_only_integer([&quot;String&quot;, True, 3.3, 1]) ➞ [1]

# %%
def return_only_integer(l):
    x = len(l)
    i=0
    while(i<len(l)):
        if(type(l[i])==int):
            i = i+1
        else:
            l.remove(l[i])
            continue
        
    return l

l1 = ["hello", 81, "basketball", 123, "fox"]
print(l1)
print("--> ",return_only_integer(l1))

l2 = [10, "121", 56, 20, "car", 3, "lion"]
print(l2)
print("--> ",return_only_integer(l2))

l3 = ["String", True, 3.3, 1]
print(l3)
print("--> ",return_only_integer(l3))
# Out:
# ['hello', 81, 'basketball', 123, 'fox']
# -->  [81, 123]
# [10, '121', 56, 20, 'car', 3, 'lion']
# -->  [10, 56, 20, 3]
# ['String', True, 3.3, 1]
# -->  [1]
