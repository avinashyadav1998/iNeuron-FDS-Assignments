# %% [markdown]
# 1. Write a Python Program to Find LCM?

# %%
def lcm(x,y):
    if(x>y):
        g = x
    else:
        g = y
    
    while(True):
        if(g%x==0 and g%y==0):
            lcm = g
            break
        g =  g + 1
    return lcm


x = int(input("Enter 1st no : "))
y = int(input("Enter 2nd no : "))
print("LCM is : ",lcm(x,y))
# Out:
# Enter 1st no : 12
# Enter 2nd no : 20
# LCM is :  60

# %% [markdown]
# 2. Write a Python Program to Find HCF?

# %%
def hcf(x,y):
    if(x==0):
        return y
    return hcf(y%x,x)

x = int(input("Enter 1st no : "))
y = int(input("Enter 2nd no : "))
print("HCF is : ",hcf(x,y))
# Out:
# Enter 1st no : 12
# Enter 2nd no : 20
# HCF is :  4

# %% [markdown]
# 3. Write a Python Program to Convert Decimal to Binary, Octal and Hexadecimal?

# %%
x = int(input("Enter a no : "))
print("The decimal value of",x, "is:")
print(bin(x), "in binary.")
print(oct(x), "in octal.")
print(hex(x), "in hexadecimal.")
# Out:
# Enter a no : 11
# The decimal value of 11 is:
# 0b1011 in binary.
# 0o13 in octal.
# 0xb in hexadecimal.

# %% [markdown]
# 4. Write a Python Program To Find ASCII value of a character?

# %%
c = input("Enter a character : ")
print("ASCII value of{0} is {1}".format(c,ord(c)))
# Out:
# Enter a character : Z
# ASCII value ofZ is 90

# %% [markdown]
# 5. Write a Python Program to Make a Simple Calculator with 4 basic mathematical operations?

# %%
def add(n1, n2):
    
    return n1 + n2 
   
def subtract(n1, n2):
    
    return n1 - n2 
  
def multiply(n1, n2): 
    
    return n1 * n2 
  
def divide(n1, n2): 
    if(n2>0):
        return n1 / n2 

def cal(i):
        switcher={
                '+' : add(n1,n2),
                '-' : subtract(n1, n2),
                '*' : multiply(n1, n2),
                '/' : divide(n1, n2)
             }
        return switcher.get(i,"Invalid operation")
  
n1 = int(input("Enter no 1 : "))
n2 = int(input("Enter no 2 : "))
print("Please select operation -\n"
        "+. Add\n" 
        "-. Subtract\n" 
        "*. Multiply\n" 
        "/. Divide\n") 
i = input("")
print("arithmetic opertation : ",i)
print("Result of arithmetic opertation : ",cal(i))
# Out:
# Enter no 1 : 44
# Enter no 2 : 7
# Please select operation -
# +. Add
# -. Subtract
# *. Multiply
# /. Divide
#
# /
# arithmetic opertation :  /
# Result of arithmetic opertation :  6.285714285714286
